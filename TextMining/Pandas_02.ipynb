# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.3'

# %%
numbers = [1, 2, 3, 4, 5]
list_sr = pd.Series(numbers)
print(list_sr)
type(list_sr)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# pandas.core.series.Series

# %%
print(list_sr.dtype, list_sr.shape, list_sr.size, list_sr.name)
print(list_sr.index)
print(list_sr.values)
# Out:
# int64 (5,) 5 None
# RangeIndex(start=0, stop=5, step=1)
# [1 2 3 4 5]

# %%
dict_data = {"a" : 1, "b": 2, "c" : 3, "d" : 4, "e" : 5}
dict_sr = pd.Series(dict_data)
print(dict_sr)
print(dict_sr.dtype, dict_sr.shape, dict_sr.size, dict_sr.name)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# int64 (5,) 5 None

# %%
list_sr.name = 'mySeries'
list_sr
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: mySeries, dtype: int64

# %%
list_sr.name
# Out:
# 'mySeries'

# %%
import numpy as np
sr1 = pd.Series(numbers, dtype=np.float32)
sr1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float32

# %%
chars = 'a b c d e'.split()
sr3 = pd.Series(numbers, index = chars, name='MySeries')
sr3
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: MySeries, dtype: int64

# %%
sr3.index, sr3.values
# Out:
# (Index(['a', 'b', 'c', 'd', 'e'], dtype='object'), array([1, 2, 3, 4, 5]))

# %%
list_sr.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
numbers = [1, 2, 3, 4, 5]
pd1 = pd.DataFrame(numbers)
pd1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
pd2 = pd.DataFrame(numbers, columns=['number'])
pd2
# Out:
#    number
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5

# %%
score = [['정약용', 70, 80, 100],['이순신', 100, 80, 70],['이율곡', 90, 95, 90]]
score_df = pd.DataFrame(score)
score_df
# Out:
#      0    1   2    3
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %%
score_df.columns = ['이름', '국어', '영어', '수학']
score_df
# Out:
#     이름   국어  영어   수학
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %%
score_df2 = pd.DataFrame(score, columns = ['이름', '국어', '영어', '수학'])
score_df2
# Out:
#     이름   국어  영어   수학
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %%
score_df.shape, score_df.index, score_df.columns
# Out:
# ((3, 4),
#  RangeIndex(start=0, stop=3, step=1),
#  Index(['이름', '국어', '영어', '수학'], dtype='object'))

# %%
score_df.dtypes
# Out:
# 이름    object
# 국어     int64
# 영어     int64
# 수학     int64
# dtype: object

# %%
print(score_df.values)
# Out:
# [['정약용' 70 80 100]
#  ['이순신' 100 80 70]
#  ['이율곡' 90 95 90]]

# %%
score_dict = {'이름' : ['정약용', '이순신', '이율곡', '홍길동'],'국어' : [70, 100, 90, 85],'영어' : [80, 80, 95, 100],'수학' : [100, 70, 90, 90]}
score_df = pd.DataFrame(score_dict)
score_df
# Out:
#     이름   국어   영어   수학
# 0  정약용   70   80  100
# 1  이순신  100   80   70
# 2  이율곡   90   95   90
# 3  홍길동   85  100   90

# %%
score_df['사회'] = [85, 88, 92, 96]
score_df
# Out:
#     이름   국어   영어   수학  사회
# 0  정약용   70   80  100  85
# 1  이순신  100   80   70  88
# 2  이율곡   90   95   90  92
# 3  홍길동   85  100   90  96

# %%
score_df['총점'] = score_df.국어 + score_df.영어 + score_df.수학 + score_df.사회 # 있는 컬럼은 [' ']를 빼고 .컬럼명이라고 써도된다
score_df['평균'] = score_df.총점 / 4
score_df
# Out:
#     이름   국어   영어   수학  사회   총점     평균
# 0  정약용   70   80  100  85  335  83.75
# 1  이순신  100   80   70  88  338  84.50
# 2  이율곡   90   95   90  92  367  91.75
# 3  홍길동   85  100   90  96  371  92.75

# %%
x = [0, 1, 2, 3, 4, 5]
y = [0, 2, 4, 6, 8, 10]
df = pd.DataFrame()
df['x'] = x
df['y'] = y
df['x * y'] = df.x + df['y']
df
# Out:
#    x   y  x * y
# 0  0   0      0
# 1  1   2      3
# 2  2   4      6
# 3  3   6      9
# 4  4   8     12
# 5  5  10     15

# %%
score_df.drop(['이름'], axis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 score_df.drop(['이름'], axis)
#
# NameError: name 'axis' is not defined

# %%
new_df = score_df.drop([0,2], axis=0)
new_df
# Out:
#     이름   국어   영어  수학  사회   총점     평균
# 1  이순신  100   80  70  88  338  84.50
# 3  홍길동   85  100  90  96  371  92.75

# %%
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#     이름   국어   영어  수학  사회   총점     평균
# 0  이순신  100   80  70  88  338  84.50
# 1  홍길동   85  100  90  96  371  92.75

# %%
#### 3-5 데이터의 접근

# %%
score_df
# Out:
#     이름   국어   영어   수학  사회   총점     평균
# 0  정약용   70   80  100  85  335  83.75
# 1  이순신  100   80   70  88  338  84.50
# 2  이율곡   90   95   90  92  367  91.75
# 3  홍길동   85  100   90  96  371  92.75

# %%
score_df['이름']
# Out:
# 0    정약용
# 1    이순신
# 2    이율곡
# 3    홍길동
# Name: 이름, dtype: object

# %%
score_df[['이름', '총점']]
# Out:
#     이름   총점
# 0  정약용  335
# 1  이순신  338
# 2  이율곡  367
# 3  홍길동  371

# %%
score_df[1] #KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 score_df[1] #KeyError
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 1

# %%
score_df[1:2]
# Out:
#     이름   국어  영어  수학  사회   총점    평균
# 1  이순신  100  80  70  88  338  84.5

# %%
score_df[1:][['이름','총점']]
# Out:
#     이름   총점
# 1  이순신  338
# 2  이율곡  367
# 3  홍길동  371

# %%
#### 3-5-1 직접 접근 방식

# %%
#### 3-5-2. Boolean Indexing

# %%
score_df[score_df.수학>80]
# Out:
#     이름  국어   영어   수학  사회   총점     평균
# 0  정약용  70   80  100  85  335  83.75
# 2  이율곡  90   95   90  92  367  91.75
# 3  홍길동  85  100   90  96  371  92.75

# %%
score_df[(score_df.국어>80) & (score_df.영어>90)]
# Out:
#     이름  국어   영어  수학  사회   총점     평균
# 2  이율곡  90   95  90  92  367  91.75
# 3  홍길동  85  100  90  96  371  92.75

# %%
score_df[score_df['이름'].isin(['정약용', '이순신'])]
# Out:
#     이름   국어  영어   수학  사회   총점     평균
# 0  정약용   70  80  100  85  335  83.75
# 1  이순신  100  80   70  88  338  84.50

# %%
#### 3-5-3. 인덱서를 이용한 접근 (loc, iloc)

# %%
score_df
# Out:
#     이름   국어   영어   수학  사회   총점     평균
# 0  정약용   70   80  100  85  335  83.75
# 1  이순신  100   80   70  88  338  84.50
# 2  이율곡   90   95   90  92  367  91.75
# 3  홍길동   85  100   90  96  371  92.75

# %%
score_df.loc[0:2,'국어':'수학']
# Out:
#     국어  영어   수학
# 0   70  80  100
# 1  100  80   70
# 2   90  95   90

# %%
score_df.iloc[0:2, 1:3]
# Out:
#     국어  영어
# 0   70  80
# 1  100  80

# %%
filename = './data/sample_data.csv'
sample_df = pd.read_csv(filename)
sample_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[70], line 2
#       1 filename = './data/sample_data.csv'
# ----> 2 sample_df = pd.read_csv(filename)
#       3 sample_df
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\anaconda3\envs\textmine26\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/sample_data.csv'

# %%
sample_df.tail(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 sample_df.tail(3)
#
# NameError: name 'sample_df' is not defined

# %%
len(sample_df), sample_df.shape

# %%
sample_df.describe()

# %%
sample_df['City'].value_counts()
