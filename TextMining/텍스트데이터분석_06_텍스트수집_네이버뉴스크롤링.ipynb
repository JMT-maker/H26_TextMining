# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Hxf75lCgv8VYAV1wQ6tA"
client_secret = "Th4uBMYXiw"

encText = urllib.parse.quote("뉴스")

start = 1
display = 15
while start <= 20:
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
    url += '&start=' + str(start) + '&display=15' # 검색 시작 위치로 start, 최대 15개까지 결과 출력
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
        break
    start += display
# Out:
# {
# 	"lastBuildDate":"Thu, 30 Apr 2026 20:43:59 +0900",
# 	"total":23870207,
# 	"start":1,
# 	"display":15,
# 	"items":[
# 		{
# 			"title":"한국에는 '1천 명'의 <b>뉴스<\/b> 조직이 가능한가?",
# 			"link":"https:\/\/www.onlinejournalism.co.kr\/m\/1196231310",
# 			"description":"<b>뉴스<\/b>미디어의 미래 한국에는 '1천 명'의 <b>뉴스<\/b> 조직이 가능한가? 수레바퀴 2025. 11. 30. 17:28 한국에는 뉴욕타임스, 워싱턴포스트, 월스트리트저널, 가디언 같은 매체가 있는가? 교역 규모, 문화적 위상은 선진국... ",
# 			"bloggername":"최진순 기자의 온라인저널리즘의 산실",
# 			"bloggerlink":"https:\/\/www.onlinejournalism.co.kr\/",
# 			"postdate":"20251130"
# 		},
# 		{
# 			"title":"오늘의 부동산 <b>뉴스<\/b> 브리핑 (2026.4.9)",
# 			"link":"https:\/\/blog.naver.com\/myway855\/224245993230",
# 			"description":"오늘의 부동산 <b>뉴스<\/b> 브리핑 (2026.4.9) 1️⃣ 서울 전세 급감 → 30대 매수 증가 ㆍ서울 전세 매물이... 띠별운세 #부동산<b>뉴스<\/b>, 오늘부동산<b>뉴스<\/b>, 2026부동산전망, 서울아파트전망, 서울집값전망, 전세부족... ",
# 			"bloggername":"【김영숙중개사】",
# 			"bloggerlink":"blog.naver.com\/myway855",
# 			"postdate":"20260409"
# 		},
# 		{
# ...

# %% [markdown]
# ## 네이버 검색 API 예제 코드

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Hxf75lCgv8VYAV1wQ6tA"
client_secret = "Th4uBMYXiw"

encText = urllib.parse.quote("뉴스")

start = 1
display = 15
    
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
url += '&start=' + str(start) + '&display=15' # 검색 시작 위치로 start, 최대 15개까지 결과 출력
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    news_json = response_body.decode('utf-8')
    print(news_json)
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 30 Apr 2026 20:44:00 +0900",
# 	"total":55550021,
# 	"start":1,
# 	"display":15,
# 	"items":[
# 		{
# 			"title":"교체 투입된 이민우",
# 			"originallink":"https:\/\/www.news1.kr\/photos\/7885755",
# 			"link":"https:\/\/m.sports.naver.com\/kbaseball\/article\/421\/0008922291",
# 			"description":"30일 대전 한화생명볼파크에서 열린 2026 신한 SOL KBO리그 SSG 랜더스와 한화 이글스 경기에서 교체 투입된 한화 투수 이민우가 역투하고 있다. 2026.4.30\/<b>뉴스<\/b>1",
# 			"pubDate":"Thu, 30 Apr 2026 20:42:00 +0900"
# 		},
# 		{
# 			"title":"&quot;딸, 눈에 넣어도 안 아파&quot; 故 박동빈 별세, 54세 늦깎이 아빠 비보 먹먹",
# 			"originallink":"https:\/\/www.xportsnews.com\/article\/2143660",
# 			"link":"https:\/\/m.entertain.naver.com\/article\/311\/0002005904",
# 			"description":"엑스포츠<b>뉴스<\/b>에 &quot;다른 딸바보들의 뺨을 칠 만큼 딸바보다. 눈에 넣어도 안 아프다는 말을 실감한다. 이렇게 소중한 아이가 우리에게 와줘서 고맙다”라고 말하며 부성애를 드러낸 바 있다. 고인은 엑스포츠<b>뉴스<\/b>와의... ",
# 			"pubDate":"Thu, 30 Apr 2026 20:41:00 +0900"
# 		},
# 		{
# 			"title":"종묘 정전서 선보이는 종묘제례악 야간 공연",
# ...

# %%
news_json = json.loads(news_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 news_json = json.loads(news_data)
#
# NameError: name 'json' is not defined

# %%
import json

py_news_data = json.loads(news_data)
type(py_news_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 import json
# ----> 3 py_news_data = json.loads(news_data)
#       4 type(py_news_data)
#
# NameError: name 'news_data' is not defined

# %%
py_news_data['items']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 py_news_data['items']
#
# NameError: name 'py_news_data' is not defined

# %%
news_corpus = []
news_corpus += py_news_data['items']
news_corpus
